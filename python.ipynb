# %% [markdown]
# <a href="https://colab.research.google.com/github/warpheard/estudosfaculdade/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("subtração")

a = int (input("número: "))
b = int (input("número: "))

subtração = a - b
print("subtração", subtração)
# Out:
# subtração
# número: 3
# número: 1
# subtração 2

# %%
print("adição")

a = int (input("número: "))
b = int (input("número: "))

adição = a + b
print("adição", adição)
# Out:
# adição
# número: 2
# número: 3
# adição 5

# %%
print("multiplicação")

a = int (input("número: "))
b = int (input("número: "))

multiplicação = a * b
print("multiplicação", multiplicação)
# Out:
# multiplicação
# número: 2
# número: 3
# multiplicação 6

# %%
print("divisao")

a = int (input("número: "))
b = int (input("número: "))

divisao = a / b
print("divisao", divisao)
# Out:
# divisao
# número: 10
# número: 2
# divisao 5.0

# %%
print("antecessor e sucessor")

numero = int (input("número: "))

antecessor = numero - 1
sucessor = numero + 1
print("antecessor", antecessor)
print("sucessor", sucessor)
# Out:
# antecessor e sucessor
# número: 2
# antecessor 1
# sucessor 3

# %%
print("dobro e triplo")

a = int(input("numero:"))

dobro = a * 2
triplo = a * 3
print("dobro:", dobro)
print("triplo:", triplo)
# Out:
# dobro e triplo
# numero:1
# dobro:  2
# triplo:  3
